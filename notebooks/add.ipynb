# %%
def add(a, b):
    return a + b

# %%
add(1,1)
# Out:
# 2

# %%
add(2,2)
# Out:
# 4

# %%
def sum_list(values):
    total = 0
    for value in values:
        total = add(total, value)
    return total

# %%
values1 = [1, 2, 3, 4, 5]
test1 = sum_list(values1)

print(f"Sum of {values1} is {test1}")
# Out:
# Sum of [1, 2, 3, 4, 5] is 15
